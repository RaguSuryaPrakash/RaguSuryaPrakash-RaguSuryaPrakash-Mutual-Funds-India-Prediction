# %%
import pandas as pd

# %%
# Read the preprocessed CSV file
dataset = pd.read_csv('preprocessed.csv')

# %%
dataset
# Out:
#      min_sip  min_lumpsum  expense_ratio  fund_size_cr  fund_age_yr  \
# 0        100          100           0.27            10           10
# 1       1000         1000           0.36          4288           10
# 2       1000         1000           0.53           157           10
# 3        500         1000           0.76           637            4
# 4        100          100           0.61          6386           10
# ..       ...          ...            ...           ...          ...
# 144      500          500           0.35          1238            5
# 145      500          500           0.33          2463           10
# 146      500          500           0.39           333           10
# 147      500          500           0.25          2065            5
# 148      500          500           0.38           210           10
#
#      risk_level  rating  returns_1yr  returns_3yr  returns_5yr sortino  alpha  \
# ...

# %%
# Inspect the DataFrame
print(dataset.head())
# Out:
#    min_sip  min_lumpsum  expense_ratio  fund_size_cr  fund_age_yr  risk_level  \
# 0      100          100           0.27            10           10           3
# 1     1000         1000           0.36          4288           10           1
# 2     1000         1000           0.53           157           10           5
# 3      500         1000           0.76           637            4           6
# 4      100          100           0.61          6386           10           6
#
#    rating  returns_1yr  returns_3yr  returns_5yr sortino  alpha     sd  beta  \
# 0       3          4.0          6.5          6.9    0.32   2.24   9.39  0.01
# 1       3          5.6          4.8          5.5    1.33   1.53   0.72  0.56
# 2       3          2.0         18.9          9.7    3.44   2.67  10.58  0.67
# 3       2         -0.7         17.1          0.0    2.18  -6.37  14.99  0.85
# 4       4          4.5         18.6          9.7    3.69   1.99  10.38  0.68
#
#   sharpe
# 0   0.24
# 1    1.1
# ...

# %% [markdown]
# # Graphical Data Visualisation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # How does the risk_level  vary between returns_1yr: Returns (1 Year) and returns_5yr: Returns (5 Years)

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='risk_level', y='returns_1yr', data=dataset.sort_values("alpha")).set_title('1-Year Returns by risk_level', fontsize=20)
plt.figure(figsize=(10, 5))
sns.barplot(x='risk_level', y='returns_5yr', data=dataset.sort_values("alpha")).set_title('5-Year Returns by risk_level', fontsize=20)
# Out:
# Text(0.5, 1.0, '5-Year Returns by risk_level')

# %% [markdown]
# # sing the given code structure with plt.figure(), plt.subplot(), and sns.boxplot() allows you to create a complex figure with multiple subplots. Each subplot can display different aspects of your dataset in a structured and organized manner.

# %%
plt.figure(figsize = (18,5))
plt.subplot(2,2,1)
sns.boxplot(x = 'min_lumpsum', data = dataset)
# Out:
# <Axes: xlabel='min_lumpsum'>

# %% [markdown]
# # from this graph, we can see mean and median
# # mean is around 1000 and median is approximately 7000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (18,5))
plt.subplot(1,2,2)
sns.histplot(x = 'min_sip', data = dataset, kde = True)
# Out:
# C:\Users\ragus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='min_sip', ylabel='Count'>

# %% [markdown]
# # From this histplot, we can understand that most of the people min_sip: Minimum Systematic Investment Plan range between 10 to 1000

# %% [markdown]
# # Business flights are only available in FIVE scheme_name :
# # (1)Aditya Birla SL Active Debt Multi-Mgr FoF-Dir
# # (2)Aditya Birla SL Arbitrage Fund
# # (3)Aditya Birla SL Asset Allocator FoF-Dir Growth
# # (4)Aditya Birla SL Bal Bhavishya Yojna – Dir Growth
# # (5)Aditya Birla SL Balanced Advantage Fund
# # Also, there is a big gap between the SCHEME IN YEARLY RETURNS returns_1yr	returns_3yr	returns_5yr.

# %% [markdown]
# # Does SCHEME vary YEARLY RETURNS?

# %% [markdown]
# # We will use violine plot for visualising YEARLY RETURNS 1 TO 5

# %%
fig, axs = plt.subplots(1, 3, gridspec_kw={'width_ratios': [5, 3, 3]}, figsize=(25, 5))
sns.violinplot(y="returns_1yr", x="category", data=dataset.sort_values("alpha", ascending=False), ax=axs[0])
axs[0].set_title("Returns (1 Year) by Category", fontsize=20)
sns.violinplot(y="returns_3yr", x="category", data=dataset.sort_values("alpha", ascending=False), ax=axs[1])
axs[1].set_title("Returns (3 Years) by Category", fontsize=20)
sns.violinplot(y="returns_5yr", x="category", data=dataset.sort_values("alpha", ascending=False), ax=axs[2])
axs[2].set_title("Returns (5 Years) by Category", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Returns (5 Years) by Category')

# %% [markdown]
# ## Returns (1 Year) by Category
# # ![Returns (1 Year) by Category](returns_1yr_by_category.png)
# # - The violin plot displays the distribution of 1-year returns by fund category.
# # - Large-cap funds have the highest median returns, followed by mid-cap and small-cap funds.
# # - However, the distribution of returns for small-cap funds is wider, indicating higher variability.

# %% [markdown]
# # Returns (3 Years) by Category
# # ![Returns (3 Years) by Category](returns_3yr_by_category.png)
# # - Similar to the 1-year returns, large-cap funds exhibit the highest median returns over a 3-year period.
# # - However, the spread of returns for mid-cap funds is narrower compared to the 1-year returns.

# %% [markdown]
# # Returns (5 Years) by Category
# # ![Returns (5 Years) by Category](returns_5yr_by_category.png)
# # - Large-cap funds continue to have the highest median returns over a 5-year period.
# # - The distribution of returns for small-cap funds remains wide, indicating higher risk.
# # - Overall, investors may consider large-cap funds for consistent returns over different time periods.

# %% [markdown]
# # ## Conclusion
# # - Large-cap funds consistently show higher median returns compared to mid-cap and small-cap funds.
# # - However, investors should consider the risk associated with each category before making investment decisions.

# %%
dataset_temp = dataset.groupby(['fund_age_yr'])['expense_ratio'].mean().reset_index()
plt.figure(figsize=(15, 6))
ax = sns.rugplot(x="fund_age_yr", y="expense_ratio", data=dataset_temp).set_title("Average Expense Ratio depending on Fund Age (Years)", fontsize=15)
ax = sns.stripplot(x="fund_age_yr", y="expense_ratio", data=dataset_temp)
# Out:
# C:\Users\ragus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ragus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ragus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## Average Expense Ratio by Fund Age
# # ![Average Expense Ratio by Fund Age](expense_ratio_by_fund_age.png)
# # - The rug plot displays the distribution of fund ages along the x-axis.
# # - Each tick on the rug plot represents a fund with its respective age.
# # - The strip plot overlays individual data points on top of the rug plot to show the distribution more clearly.
# # - From the visualization, we can observe any patterns or trends in the relationship between fund age and average expense ratio.

# %% [markdown]
# # Conclusion
# # - There appears to be some variability in the average expense ratio across different fund ages.
# # - Further analysis may be needed to determine if there is a significant correlation between fund age and expense ratio.
#  # - Understanding how expense ratios change over the lifespan of mutual funds can provide valuable insights for investors and fund managers.

# %%
dataset_temp = dataset.groupby(['fund_age_yr'])['expense_ratio'].mean().reset_index()
plt.figure(figsize=(15, 6))
ax = sns.scatterplot(x="fund_age_yr", y="expense_ratio", data=dataset_temp).set_title("Average Expense Ratio depending on Fund Age (Years)", fontsize=15)

# %% [markdown]
# # Does the average expense ratio of mutual funds change as the fund ages?

# %% [markdown]
# ## Analysis
# # Scatter Plot: Average Expense Ratio vs. Fund Age
# # Question**: Does the expense ratio change with the duration of the flight?
# # Method**: We grouped the dataset by the fund's age in years and calculated the mean expense ratio for each group.
# # Findings**: The scatter plot shows the relationship between the fund's age (in years) and the average expense ratio. Each point represents a fund, and its position on the plot indicates its age and average expense ratio.
# # Interpretation**: By examining the scatter plot, we can determine if there's a trend or pattern in the relationship between fund age and expense ratio.

# %% [markdown]
# # Based on the scatter plot, we can determine if there's a correlation between fund age and expense ratio.
# # - Further analysis may be needed to understand any observed trends or patterns and their implications for investors.

# %% [markdown]
# # Do mutual fund expense ratios vary depending on the departure and arrival times?

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
sns.boxplot(data=dataset, y="expense_ratio", x="fund_age_yr", showfliers=False).set_title("Average Expense Ratio based on Fund Age (Years)", fontsize=15)
plt.subplot(1, 2, 2)
sns.boxplot(data=dataset, y="expense_ratio", x="risk_level", showfliers=False).set_title("Average Expense Ratio based on Risk Level", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Average Expense Ratio based on Risk Level')

# %% [markdown]
# # Do mutual fund expense ratios vary based on the fund's age (in years) and risk level?

# %% [markdown]
# # Box Plot: Average Expense Ratio vs. Fund Age

# %% [markdown]
# # We grouped the dataset by fund age (in years) and calculated the average expense ratio for each group.
#  # The box plot displays the distribution of expense ratios based on fund ages. Each box represents the interquartile range (IQR) of expense ratios for a specific fund age.
# # By examining the box plot, we can determine if there's a trend or pattern in the relationship between fund age and expense ratio.

# %% [markdown]
# # Box Plot: Average Expense Ratio vs. Risk Level

# %% [markdown]
# #  We grouped the dataset by risk level and calculated the average expense ratio for each group.
# # The box plot displays the distribution of expense ratios based on risk levels. Each box represents the interquartile range (IQR) of expense ratios for a specific risk level.
# # By examining the box plot, we can determine if there's a correlation between risk level and expense ratio.

# %% [markdown]
#  # Based on the box plots, we can determine if there's a relationship between fund age, risk level, and expense ratio.
#  # Further analysis may be needed to understand any observed trends or patterns and their implications for investors.
